# %%
import modules.experiment.fov as expfov
import modules.plots.experimental_data as expplots

from modules_reloader import reloader
relmod = reloader(expfov, expplots)

# %%
relmod()
fov = expfov.PmtFov.for_event(10699)
f, a = expplots.plot_fov(fov, filename='experimental-pmt-fov-example')

# %%
import numpy as np

np.loadtxt('../experimental-data/FEU84-3.quanteff')
# Out:
# array([[200., 201., 202., ..., 698., 699., 700.],
#        [  0.,   0.,   0., ...,   0.,   0.,   0.]])
